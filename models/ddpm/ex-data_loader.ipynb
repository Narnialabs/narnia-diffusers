# %%
from data_loader import ImageLoader
from data_utils import *

pp = ImageLoader('../../datasets/lib/images/', 
                  img_fomat='png',
                  img_size=128,
                  batch_size=8,
                 
                  shuffle = True,
                  reverse = True,
                  padding = True,
                 
                  ratio_aug = True,
                  erode_aug = True,
                  rotate_aug = True,
                  hflip_aug = True,
                  vflip_aug = True,
               )

# %%
for idx in range(3):
    batch = pp.get_batch(idx)
    grid_imgs(batch[:,0])

# %%
from data_loader import ImageLoader
from data_utils import *

pp = ImageLoader('../../datasets/kh_ptn/', 
                  img_fomat='jpg',
                  img_size=128,
                  batch_size=8,
                 
                  shuffle = True,
                  reverse = True,
                  padding = True,
                 
                  ratio_aug = True,
                  erode_aug = False,
                  rotate_aug = False,
                  hflip_aug = True,
                  vflip_aug = True,
               )

# %%
for idx in range(3):
    batch = pp.get_batch(idx)
    grid_imgs(batch[:,0])

# %%
from data_loader import ImageLoader
from data_utils import *

pp = ImageLoader('../../datasets/wheels/wheel_topo/', 
                  img_fomat='jpg',
                  img_size=128,
                  batch_size=8,
                 
                  shuffle = True,
                  reverse = True,
                  padding = True,
                 
                  ratio_aug = False,
                  erode_aug = False,
                  rotate_aug = True,
                  hflip_aug = True,
                  vflip_aug = True,
               )

# %%
for idx in range(3):
    batch = pp.get_batch(idx)
    grid_imgs(batch[:,0])
